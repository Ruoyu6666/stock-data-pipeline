# %%
import pandas as pd
import yfinance as yf

# %%
# Scrape from Wikipedia
url = 'https://en.wikipedia.org/wiki/DAX'
wiki_tables = pd.read_html(url)
dax_table = wiki_tables[4]
dax_tickers = dax_table['Ticker'].tolist()
len(dax_tickers)
# Out:
# 41

# %%
ticker = yf.Ticker("DTE.DE")
data = ticker.history(period="1d", interval="1m")  # 1-minute data

# %%
ticker2 = yf.Ticker("RHM.DE")
data2 = ticker2.history(period="1d", interval="5m")  # 1-minute data

# %%
data2
# Out:
#                              Open    High     Low   Close  Volume  Dividends  \
# Datetime
# 2025-06-06 09:00:00+02:00  1898.0  1898.0  1885.0  1890.5       0        0.0
# 2025-06-06 09:05:00+02:00  1891.0  1894.0  1885.0  1885.0    2857        0.0
# 2025-06-06 09:10:00+02:00  1884.5  1889.5  1883.0  1888.0    1197        0.0
# 2025-06-06 09:15:00+02:00  1887.5  1891.5  1880.0  1881.0    2237        0.0
# 2025-06-06 09:20:00+02:00  1882.0  1887.5  1873.0  1873.5    2443        0.0
# ...                           ...     ...     ...     ...     ...        ...
# 2025-06-06 17:05:00+02:00  1808.0  1809.0  1807.5  1808.5    2553        0.0
# 2025-06-06 17:10:00+02:00  1806.5  1807.0  1806.5  1807.0    1525        0.0
# 2025-06-06 17:15:00+02:00  1805.5  1805.5  1804.5  1804.5    2843        0.0
# 2025-06-06 17:20:00+02:00  1805.0  1805.0  1801.5  1802.0    2948        0.0
# 2025-06-06 17:25:00+02:00  1796.0  1796.5  1792.5  1792.5    9768        0.0
#
# ...
